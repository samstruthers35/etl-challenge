# %%
from bs4 import BeautifulSoup as bs
import requests
url = 'https://fbref.com/en/country/players/JAM/Jamaica-Football-Players'

# %%
url = 'https://fbref.com/en/country/players/JAM/Jamaica-Football-Players'

# %%
response = requests.get(url)
soup = bs(response.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/fb/www/base" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
#   <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202002252" rel="dns-prefetch"/>
#   <!-- no:cookie fast load the css.           -->
#   <script>
#    function gup(n) {n = n.replace(/[\[]/, '\\[').replace(/[\]]/, '\\]'); var r = new RegExp('[\\?&]'+n+'=([^&#]*)'); var re = r.exec(location.search);   return re === null?'':decodeURIComponent(re[1].replace(/\+/g,' '));}; document.srdev = gup('srdev')
#   </script>
#   <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#   <link crossorigin="" href="https://d6rt22vwfyr3i.cloudfront.net" rel="preconnect"/>
#   <style>
# ...

# %%
results = soup.find_all('div', class_="section_content")
print(results)
# Out:
# [<div class="section_content" id="div_7382855708">
# ...

# %%
player_name = []
player_id = []
player_year = []
player_position = []
for result in results:
    player_name = player_name + result.find_all('strong')

# %%
print(player_name)
# Out:
# [<strong>Sade Adamolekun</strong>, <strong>Chinyelu Asher</strong>, <strong>Rodolph Austin</strong>, <strong>Leon Bailey</strong>, <strong>Giles Barnes</strong>, <strong>Akeil Barrett</strong>, <strong>Zaire Bartley</strong>, <strong>Deshane Beckford</strong>, <strong>Cardel Benbow</strong>, <strong>Deneisha Blackwood</strong>, <strong>Andre Blake</strong>, <strong>Dominique Bond-Flasza</strong>, <strong>Neco Brett</strong>, <strong>Amoy Brown</strong>, <strong>Brian Brown</strong>, <strong>Deshorn Brown</strong>, <strong>Jevani Brown</strong>, <strong>Jody Brown</strong>, <strong>Cory Burke</strong>, <strong>Tiffany Cameron</strong>, <strong>Sashana Campbell</strong>, <strong>Trudi Carter</strong>, <strong>Willis Chavany</strong>, <strong>Rennico Clarke</strong>, <strong>Andre Clennon</strong>, <strong>Kadeem Dacres</strong>, <strong>Keammar Daley</strong>, <strong>Nicque Daley</strong>, <strong>Rashawn Dally</strong>, <strong>Martin Davis</strong>, <strong>Clayton Donaldson</strong
# ...

# %%
print(player_name[0])
# Out:
# <strong>Sade Adamolekun</strong>

# %%
#for row in soup.find_all('div',attrs={"class" : "section_content"}):
 #   print(row.text)

# %%
#player_name = [a['href'] for a in soup.find_all('p', href=True)]
#print(player_name)

# %%
#player_name = soup.find('p').getText()
#for players in player_name:
#    print(player_name)

# %%
results = soup.find()
